# %% [markdown]
# # Download Data

# %%
# !wget https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/concrete_crack_images_for_classification.zip -P ./resources/data
# Out:
# --2020-09-01 07:35:38--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/concrete_crack_images_for_classification.zip
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 245259777 (234M) [application/zip]
# Saving to: ‘./resources/data/concrete_crack_images_for_classification.zip’
#
# concrete_crack_imag 100%[===================>] 233.90M  24.0MB/s    in 8.1s
#
# 2020-09-01 07:35:47 (28.8 MB/s) - ‘./resources/data/concrete_crack_images_for_classification.zip’ saved [245259777/245259777]

# %%
# !unzip -q  ./resources/data/concrete_crack_images_for_classification.zip -d  ./resources/data

# %% [markdown]
# # Imports and Auxillary Functions
#
# The following are the libraries we are going to use for this lab:

# %%
from PIL import Image
from matplotlib.pyplot import imshow
import pandas
import matplotlib.pylab as plt
import os
import glob

# %% [markdown]
# We will use this function in the lab to plot:

# %%
def show_data(data_sample, shape = (28, 28)) :
    plt.imshow(data_sample[0].numpy().reshape(shape), cmap='gray')
    plt.title('y = ' + data_sample[1])

# %% [markdown]
# # Examine Files
#
# In this section we are going to get a list of the negative image files, then plot them. Then for the first question your job to something similae to the positive files.
#
# The path to all the images are stored in the variable `directory`.

# %%
directory = "./resources/data"

# %% [markdown]
# The images with out the cracks are stored in the file Negative

# %%
negative='Negative'

# %% [markdown]
# We can find the path to the file with all the negative images by using the function `os.path.join`. Inputs are the variable directory as well as the variable `negative`.

# %%
negative_file_path = os.path.join(directory,negative)
negative_file_path
# Out:
# './resources/data/Negative'

# %% [markdown]
# ### Loading the File of Each Image
#
# We need each path of each image, we can find all the files in the directory `negative_file_path` using the function `os.listdir`, the result is a list. We print out the first three elements of the list.

# %%
os.listdir(negative_file_path)[0:3]
# Out:
# ['00001.jpg', '00002.jpg', '00003.jpg']

# %% [markdown]
# We need the full path of the image so we join them as above, here are a few samples.

# %%
[os.path.join(negative_file_path, file) for file in os.listdir(negative_file_path)][0:3]
# Out:
# ['./resources/data/Negative/00001.jpg',
#  './resources/data/Negative/00002.jpg',
#  './resources/data/Negative/00003.jpg']

# %% [markdown]
# In some cases, we may have files of a different type, so we have to ensure it's of type jpeg. We have to check the extension using the method `endswith()`. The method returns **True** if the string ends with the specified suffix, otherwise **False**.

# %%
print("test.jpg".endswith(".jpg"))
print("test.mpg".endswith(".jpg"))
# Out:
# True
# False

# %% [markdown]
# We now have all the tools to create a list with the path to each image file. We use a List Comprehension to make the code more compact. We assign it to the vairable `negative_files`, sort it and display the first three elements:

# %%
negative_files = [os.path.join(negative_file_path, file) for file in os.listdir(negative_file_path) if file.endswith(".jpg")]
negative_files.sort()
negative_files[0:3]
# Out:
# ['./resources/data/Negative/00001.jpg',
#  './resources/data/Negative/00002.jpg',
#  './resources/data/Negative/00003.jpg']

# %% [markdown]
# <h2 id="Question_1">Question 1</h2>

# %% [markdown]
# Using the procedure above, load all the images with cracks paths into a list called positive files, the directory of these images is called Positive.  Make sure the list is sorted and display the first three elements of the list you will need this for the question so remember it.

# %%
positive_directory_path = os.path.join(directory, "Positive")

positive_files = [os.path.join(positive_directory_path, file) for file in os.listdir(positive_directory_path) if file.endswith(".jpg")]
positive_files[0:3]
# Out:
# ['./resources/data/Positive/00001.jpg',
#  './resources/data/Positive/00002.jpg',
#  './resources/data/Positive/00003.jpg']

# %% [markdown]
# ### Display and Analyze Image With No Cracks
#
# We can oprn an image by using the `Image` Module in the PIL library, using the function open. We only require the image path, the input is the path of the image. For example we can load the first image as follows:

# %%
image1 = Image.open(negative_files[0])

# %% [markdown]
# we can plot the image

# %%
plt.imshow(image1)
plt.title("1st image with no cracks")
plt.show()

# %%
image2 = Image.open(negative_files[1]) 
plt.imshow(image2)
plt.title("2nd Image with no cracks")
plt.show()

# %%
for i in range(3):
    
    image = Image.open(positive_files[i])
    plt.imshow(image)
    plt.show()
